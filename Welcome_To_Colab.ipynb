# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikatyagi071-lang/50-questions-of-python-18-03-26-/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def simple_interest(p, r, t):
    return (p * r * t) / 100

p = float(input("Enter P: "))
r = float(input("Enter R: "))
t = float(input("Enter T: "))

print("Simple Interest:", simple_interest(p, r, t))1
# Out:
# Enter P: 15
# Enter R: 17
# Enter T: 19
# Simple Interest: 48.45
